# %% [markdown]
# <a href="https://colab.research.google.com/github/avril-rdgz/SCEDS_TVMA/blob/main/Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part I. Code replication

# %% [markdown]
# Packages and data load

# %% [markdown]
# Model

# %% [markdown]
# Methodology: Estimator

# %% [markdown]
# Methodology: Comaprison
